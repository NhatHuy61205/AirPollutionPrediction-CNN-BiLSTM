# %%
from _setup import setup_project_root
PROJECT_ROOT = setup_project_root()
PROJECT_ROOT
# Out:
# WindowsPath('C:/Users/huyy/AirPollutionPrediction-CNN-BiLSTM')

# %%
import pandas as pd

data_path = PROJECT_ROOT / "data" / "Air_Quality_Processed.csv"
df = pd.read_csv(data_path)

# %%
from preprocessing.split_data import make_all_splits

infos = make_all_splits(
    input_csv_path=str(data_path),
    datetime_col="date",
    station_col="Station_No",
    train_size=0.8,
    val_size=0.1,
    test_size=0.1
)

infos
# Out:
# {'global': SplitInfo(split_type='global_split', output_dir='C:\\Users\\huyy\\AirPollutionPrediction-CNN-BiLSTM\\data\\global_split', train_path='C:\\Users\\huyy\\AirPollutionPrediction-CNN-BiLSTM\\data\\global_split\\train.csv', val_path='C:\\Users\\huyy\\AirPollutionPrediction-CNN-BiLSTM\\data\\global_split\\val.csv', test_path='C:\\Users\\huyy\\AirPollutionPrediction-CNN-BiLSTM\\data\\global_split\\test.csv', n_total=69515, n_train=55612, n_val=6951, n_test=6952, train_range=(Timestamp('2021-02-23 21:00:00'), Timestamp('2022-03-17 04:00:00')), val_range=(Timestamp('2022-03-17 04:00:00'), Timestamp('2022-05-04 11:00:00')), test_range=(Timestamp('2022-05-04 11:00:00'), Timestamp('2022-06-21 17:00:00'))),
# ...
